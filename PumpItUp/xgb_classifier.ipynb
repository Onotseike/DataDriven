# %%
import gc

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix, plot_precision_recall_curve, plot_roc_curve

from sklearn.model_selection import train_test_split as tts

from sklearn.metrics import accuracy_score, precision_score

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
class Learner():
    def __init__(self, classes : tuple, n_estimators : tuple, learning_rates : tuple, train_df : pd.DataFrame, test_df : pd.DataFrame, submission_df : pd.DataFrame):
        self.classes = classes
        self.n_estimators = n_estimators
        self.learning_rates = learning_rates
        self.train_df = train_df
        self.test_df = test_df
        self.submission_df = submission_df

        self.scored_classifiers = []
        self.classification_reports = []
    
    def split_dataset(self):        
        self.train_input, self.validation_input, self.train_output, self.validation_output = tts(self.train_df.drop(columns=["id", "status_group", "date_recorded"]), self.train_df["status_group"], test_size=0.3)
        return self.train_input, self.validation_input, self.train_output, self.validation_output
    
    def create_file(self, predicited_output, file_num : str):
        if predicited_output.shape[0] == self.submission_df.shape[0]:
            print(True)
            submission = self.submission_df.copy()
            for (idx,data) in submission["status_group"].iteritems():
                submission["status_group"][idx] = self.classes[predicited_output[idx]]                
            submission.to_csv("./datasets/submissions/submission_" + file_num + ".csv", index=False, header=True)
            del submission
            gc.collect()
    
    def create_classifier(self, learning_rate : float, estimator : int):
        classifer_model = GradientBoostingClassifier(learning_rate=learning_rate, n_estimators=estimator, max_depth=14)
        return classifer_model
    
    def train_model(self):
        dataset = self.split_dataset()
        for estimator in n_estimators:
            for learning_rate in learning_rates:
                classifier = self.create_classifier(learning_rate=learning_rate, estimator=estimator)
                classifier.fit(dataset[0], dataset[2])
                predicted_output = classifier.predict(dataset[1])
                acc_score = accuracy_score(predicted_output, dataset[3])

                self.classification_reports.append(self.create_classification_report(dataset[3], predicted_output)                )
                self.scored_classifiers.append((estimator, learning_rate, classifier, acc_score))
    
    def test_model(self, classifier : GradientBoostingClassifier,file_num : int,  create_file=True):
        self.test_df = self.test_df.fillna(self.test_df.median())
        predicted_output = classifier.predict(self.test_df.drop(columns=["id", "date_recorded"]))
        if create_file:
            self.create_file(predicted_output, str(file_num))
        return predicted_output
    
    def plot_confusion_matrix(self, classifier : GradientBoostingClassifier):
        plot_conf_matrix = plot_confusion_matrix(classifier, self.validation_input, self.validation_output, display_labels=classes, cmap=plt.cm.Blues, normalize='true') 
        return plot_conf_matrix
    
    def create_classification_report(self, validation_output, predicted_output):
        report = classification_report(validation_output, predicted_output, output_dict=True)   
        return pd.DataFrame(report).transpose()

# %% [markdown]
# ## Public Variables

# %%
classes = ("functional", "functional needs repair","non functional")
n_estimators = (400, 500)
learning_rates = (0.2,0.5,0.8)

# %%
train_df = pd.read_csv("./datasets/preprocessed_data/merged_train.csv")
test_df = pd.read_csv("./datasets/preprocessed_data/test.csv")
submission_df = pd.read_csv("./datasets/SubmissionFormat.csv")
input_columns = list(train_df.columns.values)

# %%
input_columns.remove()
["id", "date_recorded", "longitude", "latitude", "wpt_name", "region", "district_code", "recorded_by", "scheme_management", "extraction_type_group ", "extraction_type_class", "payment"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-bb880b41481b> in <module>
# ----> 1 input_columns.remove(["id", "date_recorded", "longitude", "latitude", "wpt_name"])
#
# ValueError: list.remove(x): x not in list

# %%
train_df.head(5)
# Out:
#       id  amount_tsh date_recorded  funder  gps_height  installer  longitude  \
# 0  69572      6000.0    2011-03-14  1559.0        1390     1764.0  34.938093
# 1   8776         0.0    2013-03-06  1731.0        1399     1868.0  34.698766
# 2  34310        25.0    2013-02-25  1431.0         686     1732.0  37.460664
# 3  67743         0.0    2013-01-28  1265.0         263     1254.0  38.486161
# 4  19728         0.0    2011-07-13  1555.0           0     1454.0  31.130847
#
#     latitude  wpt_name  num_private  ...  water_quality  quality_group  \
# 0  -9.856322      5520            0  ...              2              5
# 1  -2.147466     17493            0  ...              2              5
# 2  -3.821329     37342            0  ...              2              5
# 3 -11.155298        12            0  ...              2              5
# 4  -1.825359     29877            0  ...              2              5
#
#    quantity  quantity_group  source  source_type  source_class  \
# 0         3               3       3            2             2
# 1         4               4       0            0             0
# 2         3               3       5            3             0
# 3         1               1       4            5             2
# 4         2               2       0            0             0
#
#    waterpoint_type  waterpoint_type_group  status_group
# 0                0                      0             0
# 1                0                      0             0
# 2                3                      0             0
# 3                3                      0             2
# 4                0                      0             0
#
# [5 rows x 41 columns]

# %%
train_df.columns.values
# Out:
# array(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code',
#        'lga', 'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group',
#        'extraction_type_class', 'management', 'management_group',
#        'payment', 'payment_type', 'water_quality', 'quality_group',
#        'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group',
#        'status_group'], dtype=object)

# %%
test_df.head(5)
# Out:
#       id  amount_tsh date_recorded  funder  gps_height  installer  longitude  \
# 0  50785         0.0    2013-02-04  1795.0        1996     1832.0  35.290799
# 1  51630         0.0    2013-02-04  1967.0        1569     1300.0  36.656709
# 2  17168         0.0    2013-02-01  1334.0        1567     1300.0  34.767863
# 3  45559         0.0    2013-01-22   381.0         267     2349.0  38.058046
# 4  49871       500.0    2013-03-27   615.0        1260      774.0  35.006123
#
#     latitude  wpt_name  num_private  ...  payment_type  water_quality  \
# 0  -4.059696      7003            0  ...             3              2
# 1  -3.309214     14711            0  ...             3              2
# 2  -5.004344     14742            0  ...             3              2
# 3  -9.418672      7335            0  ...             2              2
# 4 -10.950412     30637            0  ...             1              2
#
#    quality_group  quantity  quantity_group  source  source_type  source_class  \
# 0              5         2               2       0            0             0
# 1              5         4               4       3            2             2
# 2              5         4               4       0            0             0
# 3              5         1               1       2            1             2
# 4              5         3               3       3            2             2
#
#    waterpoint_type  waterpoint_type_group
# 0                6                      5
# 1                0                      0
# 2                6                      5
# 3                6                      5
# 4                0                      0
#
# [5 rows x 40 columns]

# %%
submission_df.head(5)
# Out:
#       id     status_group
# 0  50785  predicted label
# 1  51630  predicted label
# 2  17168  predicted label
# 3  45559  predicted label
# 4  49871  predicted label

# %% [markdown]
# ## Train the Model then predict the test values

# %%
learner = Learner(classes=classes, n_estimators=n_estimators, learning_rates=learning_rates, train_df=train_df, test_df=test_df, submission_df=submission_df)

# %%
learner.train_model()

# %%
for report in learner.classification_reports:
    print(report)
    print()
    print("*" * 90)
    print()
# Out:
# precision    recall  f1-score       support
# 0              0.811484  0.890298  0.849066   9699.000000
# 1              0.541262  0.346542  0.422549   1287.000000
# 2              0.845948  0.786655  0.815225   6834.000000
# accuracy       0.811279  0.811279  0.811279      0.811279
# macro avg      0.732898  0.674498  0.695613  17820.000000
# weighted avg   0.805185  0.811279  0.805284  17820.000000
#
# ******************************************************************************************
#
#               precision    recall  f1-score       support
# 0              0.810916  0.880812  0.844420   9699.000000
# 1              0.497250  0.351204  0.411658   1287.000000
# 2              0.840809  0.784460  0.811658   6834.000000
# accuracy       0.805612  0.805612  0.805612      0.805612
# macro avg      0.716325  0.672159  0.689245  17820.000000
# weighted avg   0.799726  0.805612  0.800601  17820.000000
#
# ******************************************************************************************
#
#               precision    recall  f1-score       support
# 0              0.807182  0.871430  0.838076   9699.000000
# 1              0.449605  0.353535  0.395824   1287.000000
# 2              0.836831  0.775973  0.805254   6834.000000
# accuracy       0.797419  0.797419  0.797419      0.797419
# macro avg      0.697873  0.666979  0.679718  17820.000000
# weighted avg   0.792727  0.797419  0.793548  17820.000000
#
# ******************************************************************************************
#
#               precision    recall  f1-score       support
# 0              0.812100  0.889886  0.849215   9699.000000
# 1              0.534442  0.349650  0.422734   1287.000000
# 2              0.847717  0.787679  0.816596   6834.000000
# accuracy       0.811672  0.811672  0.811672      0.811672
# macro avg      0.731419  0.675738  0.696182  17820.000000
# weighted avg   0.805706  0.811672  0.805904  17820.000000
#
# ******************************************************************************************
#
#               precision    recall  f1-score      support
# 0              0.811378  0.880812  0.844671   9699.00000
# 1              0.513024  0.351981  0.417512   1287.00000
# 2              0.838951  0.786655  0.811962   6834.00000
# accuracy       0.806510  0.806510  0.806510      0.80651
# macro avg      0.721118  0.673150  0.691381  17820.00000
# weighted avg   0.800405  0.806510  0.801276  17820.00000
#
# ******************************************************************************************
#
#               precision    recall  f1-score       support
# 0              0.809615  0.873389  0.840294   9699.000000
# 1              0.464323  0.348873  0.398403   1287.000000
# 2              0.832864  0.778753  0.804900   6834.000000
# accuracy       0.799214  0.799214  0.799214      0.799214
# macro avg      0.702267  0.667005  0.681199  17820.000000
# weighted avg   0.793593  0.799214  0.794806  17820.000000
#
# ******************************************************************************************

# %%
classifiers = learner.scored_classifiers

# %%
for tuple_item in classifiers:
    plot = learner.plot_confusion_matrix(classifier=tuple_item[2])
plt.show()

# %%
for tuple_item in classifiers:
    predicted_output = learner.test_model(classifier=tuple_item[2], file_num=tuple_item[0]+tuple_item[1])
# Out:
# True
# True
# True
# True
# True
# True
